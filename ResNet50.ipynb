# %% [markdown]
# 코드를 분석해 보면 ResNet50 모델을 생성하기 위해서 반복적으로 활용하는 conv_block과 identity_block이 있을 것입니다.
# 이런 블록 구조를 잘 활용하여, 50개나 되는 복잡한 레이어 구조를 간결하게 표현하고 있는 것을 확인하실 수 있습니다

# %%
# 추가로 import해야 할 패키지들을 먼저 가져옵니다. 
import tensorflow as tf 
from tensorflow.keras import backend, regularizers, initializers, models
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.utils import plot_model


# block 안에 반복적으로 활용되는 L2 regularizer를 선언해 줍니다.
def _gen_l2_regularizer(use_l2_regularizer=True, l2_weight_decay=1e-4):
  return regularizers.l2(l2_weight_decay) if use_l2_regularizer else None

# %%
# CIFAR100 데이터셋을 가져옵시다. 
cifar100 = keras.datasets.cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train:", len(x_train), "x_test:", len(x_test))
# Out:
# x_train: 50000 x_test: 10000

# %%
def conv_blocks(input_tensor,
                kernel_size,
                filters,
                stage,
                block,
                strides=(2,2),
                use_l2_regularizer=True,
                batch_norm_decay=0.9,
                batch_norm_epsilon=1e-5):
  
  filters1,filters2,filters3=filters

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_base_name = 'conv' + str(stage) + block + '_branch'
  bn_base_name = 'bn' + str(stage) + block + '_branch'

  x = layers.Conv2D(filters1,(1,1), use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=conv_base_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters2, kernel_size, strides= strides,padding='same',use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=conv_base_name + '2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '2b')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters3,(1,1), use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=conv_base_name+'2c')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '2c')(x)


  shortcut = layers.Conv2D(filters3,(1,1),strides=strides, use_bias=False,
                           kernel_initializer='he_normal',
                           kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                           name=conv_base_name+'1')(input_tensor)

  shortcut = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '1')(shortcut)

  x = layers.add([x, shortcut])
  x = layers.Activation('relu')(x)

  return x

# %%
def identity_block(input_tensor,
                    kernel_size,
                    filters,
                    stage,
                    block,
                    use_l2_regularizer=True,
                    batch_norm_decay=0.9,
                    batch_norm_epsilon=1e-5):
  
  filters1,filters2,filters3 = filters

  if backend.image_data_format()=='channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_base_name = 'identity' + str(stage) + block + '_branch'
  bn_base_name = 'identity_bn' + str(stage) + block + '_branch'

  x = layers.Conv2D(filters1,(1,1),use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=id_base_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=batch_norm_decay,
                                epsilon=batch_norm_epsilon,
                                name=bn_base_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters2,kernel_size,padding='same',use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_base_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                         momentum = batch_norm_decay,
                         epsilon =batch_norm_epsilon,
                         name= bn_base_name+'2b')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters3,(1,1),use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_base_name+'2c')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=batch_norm_decay,
                                epsilon=batch_norm_epsilon,
                                name=bn_base_name+'2c')(x)

  x = layers.add([x,input_tensor])
  x = layers.Activation('relu')(x)

  return x

# %%
def resnet50_1(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             batch_norm_decay=0.9,
             batch_norm_epsilon=1e-5):

  input_shape = (32, 32, 3)  # CIFAR100을 위한 input_shape 조정입니다. 
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(img_input)
    bn_axis = 1
  else:  # channels_last
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      batch_norm_decay=batch_norm_decay,
      batch_norm_epsilon=batch_norm_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(img_input)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=batch_norm_decay,
      epsilon=batch_norm_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = conv_blocks(
      x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1), **block_config)
  x = identity_block(x, 3, [64, 64, 256], stage=2, block='b', **block_config)
  x = identity_block(x, 3, [64, 64, 256], stage=2, block='c', **block_config)

  x = conv_blocks(x, 3, [128, 128, 512], stage=3, block='a', **block_config)
  x = identity_block(x, 3, [128, 128, 512], stage=3, block='b', **block_config)
  x = identity_block(x, 3, [128, 128, 512], stage=3, block='c', **block_config)
  x = identity_block(x, 3, [128, 128, 512], stage=3, block='d', **block_config)

  x = conv_blocks(x, 3, [256, 256, 1024], stage=4, block='a', **block_config)
  x = identity_block(x, 3, [256, 256, 1024], stage=4, block='b', **block_config)
  x = identity_block(x, 3, [256, 256, 1024], stage=4, block='c', **block_config)
  x = identity_block(x, 3, [256, 256, 1024], stage=4, block='d', **block_config)
  x = identity_block(x, 3, [256, 256, 1024], stage=4, block='e', **block_config)
  x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f', **block_config)

  x = conv_blocks(x, 3, [512, 512, 2048], stage=5, block='a', **block_config)
  x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b', **block_config)
  x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(
          x)

  # A softmax that is followed by the model loss must be done cannot be done
  # in float16 due to numeric issues. So we pass dtype=float32.
  x = layers.Activation('softmax', dtype='float32')(x)

  # Create model.
  return models.Model(img_input, x, name='resnet50')

# %%
resnet_50 = resnet50_1(num_classes=100)
resnet_50.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_3[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9408        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation_100 (Activation)    (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_100[0][0]']
#
#  conv2a_branch2a (Conv2D)       (None, 8, 8, 64)     4096        ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['conv2a_branch2a[0][0]']
#  ion)
#
#  activation_101 (Activation)    (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  conv2a_branch2b (Conv2D)       (None, 8, 8, 64)     36864       ['activation_101[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['conv2a_branch2b[0][0]']
#  ion)
#
#  activation_102 (Activation)    (None, 8, 8, 64)     0           ['bn2a_branch2b[0][0]']
#
#  conv2a_branch2c (Conv2D)       (None, 8, 8, 256)    16384       ['activation_102[0][0]']
#
#  conv2a_branch1 (Conv2D)        (None, 8, 8, 256)    16384       ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 8, 8, 256)   1024        ['conv2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 8, 8, 256)   1024        ['conv2a_branch1[0][0]']
#  on)
#
#  add_32 (Add)                   (None, 8, 8, 256)    0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_103 (Activation)    (None, 8, 8, 256)    0           ['add_32[0][0]']
#
#  identity2b_branch2a (Conv2D)   (None, 8, 8, 64)     16384       ['activation_103[0][0]']
#
#  identity_bn2b_branch2a (BatchN  (None, 8, 8, 64)    256         ['identity2b_branch2a[0][0]']
#  ormalization)
#
#  activation_104 (Activation)    (None, 8, 8, 64)     0           ['identity_bn2b_branch2a[0][0]']
#
#  identity2b_branch2b (Conv2D)   (None, 8, 8, 64)     36864       ['activation_104[0][0]']
#
#  identity_bn2b_branch2b (BatchN  (None, 8, 8, 64)    256         ['identity2b_branch2b[0][0]']
#  ormalization)
#
#  activation_105 (Activation)    (None, 8, 8, 64)     0           ['identity_bn2b_branch2b[0][0]']
#
#  identity2b_branch2c (Conv2D)   (None, 8, 8, 256)    16384       ['activation_105[0][0]']
#
#  identity_bn2b_branch2c (BatchN  (None, 8, 8, 256)   1024        ['identity2b_branch2c[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 8, 8, 256)    0           ['identity_bn2b_branch2c[0][0]',
#                                                                   'activation_103[0][0]']
#
#  activation_106 (Activation)    (None, 8, 8, 256)    0           ['add_33[0][0]']
#
#  identity2c_branch2a (Conv2D)   (None, 8, 8, 64)     16384       ['activation_106[0][0]']
#
#  identity_bn2c_branch2a (BatchN  (None, 8, 8, 64)    256         ['identity2c_branch2a[0][0]']
#  ormalization)
#
#  activation_107 (Activation)    (None, 8, 8, 64)     0           ['identity_bn2c_branch2a[0][0]']
#
#  identity2c_branch2b (Conv2D)   (None, 8, 8, 64)     36864       ['activation_107[0][0]']
#
#  identity_bn2c_branch2b (BatchN  (None, 8, 8, 64)    256         ['identity2c_branch2b[0][0]']
#  ormalization)
#
#  activation_108 (Activation)    (None, 8, 8, 64)     0           ['identity_bn2c_branch2b[0][0]']
#
#  identity2c_branch2c (Conv2D)   (None, 8, 8, 256)    16384       ['activation_108[0][0]']
#
#  identity_bn2c_branch2c (BatchN  (None, 8, 8, 256)   1024        ['identity2c_branch2c[0][0]']
#  ormalization)
#
#  add_34 (Add)                   (None, 8, 8, 256)    0           ['identity_bn2c_branch2c[0][0]',
#                                                                   'activation_106[0][0]']
#
#  activation_109 (Activation)    (None, 8, 8, 256)    0           ['add_34[0][0]']
#
#  conv3a_branch2a (Conv2D)       (None, 8, 8, 128)    32768       ['activation_109[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 8, 8, 128)   512         ['conv3a_branch2a[0][0]']
#  ion)
#
#  activation_110 (Activation)    (None, 8, 8, 128)    0           ['bn3a_branch2a[0][0]']
#
#  conv3a_branch2b (Conv2D)       (None, 4, 4, 128)    147456      ['activation_110[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2b[0][0]']
#  ion)
#
#  activation_111 (Activation)    (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]']
#
#  conv3a_branch2c (Conv2D)       (None, 4, 4, 512)    65536       ['activation_111[0][0]']
#
#  conv3a_branch1 (Conv2D)        (None, 4, 4, 512)    131072      ['activation_109[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 4, 4, 512)   2048        ['conv3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 512)   2048        ['conv3a_branch1[0][0]']
#  on)
#
#  add_35 (Add)                   (None, 4, 4, 512)    0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_112 (Activation)    (None, 4, 4, 512)    0           ['add_35[0][0]']
#
#  identity3b_branch2a (Conv2D)   (None, 4, 4, 128)    65536       ['activation_112[0][0]']
#
#  identity_bn3b_branch2a (BatchN  (None, 4, 4, 128)   512         ['identity3b_branch2a[0][0]']
#  ormalization)
#
#  activation_113 (Activation)    (None, 4, 4, 128)    0           ['identity_bn3b_branch2a[0][0]']
#
#  identity3b_branch2b (Conv2D)   (None, 4, 4, 128)    147456      ['activation_113[0][0]']
#
#  identity_bn3b_branch2b (BatchN  (None, 4, 4, 128)   512         ['identity3b_branch2b[0][0]']
#  ormalization)
#
#  activation_114 (Activation)    (None, 4, 4, 128)    0           ['identity_bn3b_branch2b[0][0]']
#
#  identity3b_branch2c (Conv2D)   (None, 4, 4, 512)    65536       ['activation_114[0][0]']
#
#  identity_bn3b_branch2c (BatchN  (None, 4, 4, 512)   2048        ['identity3b_branch2c[0][0]']
#  ormalization)
#
#  add_36 (Add)                   (None, 4, 4, 512)    0           ['identity_bn3b_branch2c[0][0]',
#                                                                   'activation_112[0][0]']
#
#  activation_115 (Activation)    (None, 4, 4, 512)    0           ['add_36[0][0]']
#
#  identity3c_branch2a (Conv2D)   (None, 4, 4, 128)    65536       ['activation_115[0][0]']
#
#  identity_bn3c_branch2a (BatchN  (None, 4, 4, 128)   512         ['identity3c_branch2a[0][0]']
#  ormalization)
#
#  activation_116 (Activation)    (None, 4, 4, 128)    0           ['identity_bn3c_branch2a[0][0]']
#
#  identity3c_branch2b (Conv2D)   (None, 4, 4, 128)    147456      ['activation_116[0][0]']
#
#  identity_bn3c_branch2b (BatchN  (None, 4, 4, 128)   512         ['identity3c_branch2b[0][0]']
#  ormalization)
#
#  activation_117 (Activation)    (None, 4, 4, 128)    0           ['identity_bn3c_branch2b[0][0]']
#
#  identity3c_branch2c (Conv2D)   (None, 4, 4, 512)    65536       ['activation_117[0][0]']
#
#  identity_bn3c_branch2c (BatchN  (None, 4, 4, 512)   2048        ['identity3c_branch2c[0][0]']
#  ormalization)
#
#  add_37 (Add)                   (None, 4, 4, 512)    0           ['identity_bn3c_branch2c[0][0]',
#                                                                   'activation_115[0][0]']
#
#  activation_118 (Activation)    (None, 4, 4, 512)    0           ['add_37[0][0]']
#
#  identity3d_branch2a (Conv2D)   (None, 4, 4, 128)    65536       ['activation_118[0][0]']
#
#  identity_bn3d_branch2a (BatchN  (None, 4, 4, 128)   512         ['identity3d_branch2a[0][0]']
#  ormalization)
#
#  activation_119 (Activation)    (None, 4, 4, 128)    0           ['identity_bn3d_branch2a[0][0]']
#
#  identity3d_branch2b (Conv2D)   (None, 4, 4, 128)    147456      ['activation_119[0][0]']
#
#  identity_bn3d_branch2b (BatchN  (None, 4, 4, 128)   512         ['identity3d_branch2b[0][0]']
#  ormalization)
#
#  activation_120 (Activation)    (None, 4, 4, 128)    0           ['identity_bn3d_branch2b[0][0]']
#
#  identity3d_branch2c (Conv2D)   (None, 4, 4, 512)    65536       ['activation_120[0][0]']
#
#  identity_bn3d_branch2c (BatchN  (None, 4, 4, 512)   2048        ['identity3d_branch2c[0][0]']
#  ormalization)
#
#  add_38 (Add)                   (None, 4, 4, 512)    0           ['identity_bn3d_branch2c[0][0]',
#                                                                   'activation_118[0][0]']
#
#  activation_121 (Activation)    (None, 4, 4, 512)    0           ['add_38[0][0]']
#
#  conv4a_branch2a (Conv2D)       (None, 4, 4, 256)    131072      ['activation_121[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['conv4a_branch2a[0][0]']
#  ion)
#
#  activation_122 (Activation)    (None, 4, 4, 256)    0           ['bn4a_branch2a[0][0]']
#
#  conv4a_branch2b (Conv2D)       (None, 2, 2, 256)    589824      ['activation_122[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2b[0][0]']
#  ion)
#
#  activation_123 (Activation)    (None, 2, 2, 256)    0           ['bn4a_branch2b[0][0]']
#
#  conv4a_branch2c (Conv2D)       (None, 2, 2, 1024)   262144      ['activation_123[0][0]']
#
#  conv4a_branch1 (Conv2D)        (None, 2, 2, 1024)   524288      ['activation_121[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 2, 2, 1024)  4096        ['conv4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 2, 2, 1024)  4096        ['conv4a_branch1[0][0]']
#  on)
#
#  add_39 (Add)                   (None, 2, 2, 1024)   0           ['bn4a_branch2c[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_124 (Activation)    (None, 2, 2, 1024)   0           ['add_39[0][0]']
#
#  identity4b_branch2a (Conv2D)   (None, 2, 2, 256)    262144      ['activation_124[0][0]']
#
#  identity_bn4b_branch2a (BatchN  (None, 2, 2, 256)   1024        ['identity4b_branch2a[0][0]']
#  ormalization)
#
#  activation_125 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4b_branch2a[0][0]']
#
#  identity4b_branch2b (Conv2D)   (None, 2, 2, 256)    589824      ['activation_125[0][0]']
#
#  identity_bn4b_branch2b (BatchN  (None, 2, 2, 256)   1024        ['identity4b_branch2b[0][0]']
#  ormalization)
#
#  activation_126 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4b_branch2b[0][0]']
#
#  identity4b_branch2c (Conv2D)   (None, 2, 2, 1024)   262144      ['activation_126[0][0]']
#
#  identity_bn4b_branch2c (BatchN  (None, 2, 2, 1024)  4096        ['identity4b_branch2c[0][0]']
#  ormalization)
#
#  add_40 (Add)                   (None, 2, 2, 1024)   0           ['identity_bn4b_branch2c[0][0]',
#                                                                   'activation_124[0][0]']
#
#  activation_127 (Activation)    (None, 2, 2, 1024)   0           ['add_40[0][0]']
#
#  identity4c_branch2a (Conv2D)   (None, 2, 2, 256)    262144      ['activation_127[0][0]']
#
#  identity_bn4c_branch2a (BatchN  (None, 2, 2, 256)   1024        ['identity4c_branch2a[0][0]']
#  ormalization)
#
#  activation_128 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4c_branch2a[0][0]']
#
#  identity4c_branch2b (Conv2D)   (None, 2, 2, 256)    589824      ['activation_128[0][0]']
#
#  identity_bn4c_branch2b (BatchN  (None, 2, 2, 256)   1024        ['identity4c_branch2b[0][0]']
#  ormalization)
#
#  activation_129 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4c_branch2b[0][0]']
#
#  identity4c_branch2c (Conv2D)   (None, 2, 2, 1024)   262144      ['activation_129[0][0]']
#
#  identity_bn4c_branch2c (BatchN  (None, 2, 2, 1024)  4096        ['identity4c_branch2c[0][0]']
#  ormalization)
#
#  add_41 (Add)                   (None, 2, 2, 1024)   0           ['identity_bn4c_branch2c[0][0]',
#                                                                   'activation_127[0][0]']
#
#  activation_130 (Activation)    (None, 2, 2, 1024)   0           ['add_41[0][0]']
#
#  identity4d_branch2a (Conv2D)   (None, 2, 2, 256)    262144      ['activation_130[0][0]']
#
#  identity_bn4d_branch2a (BatchN  (None, 2, 2, 256)   1024        ['identity4d_branch2a[0][0]']
#  ormalization)
#
#  activation_131 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4d_branch2a[0][0]']
#
#  identity4d_branch2b (Conv2D)   (None, 2, 2, 256)    589824      ['activation_131[0][0]']
#
#  identity_bn4d_branch2b (BatchN  (None, 2, 2, 256)   1024        ['identity4d_branch2b[0][0]']
#  ormalization)
#
#  activation_132 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4d_branch2b[0][0]']
#
#  identity4d_branch2c (Conv2D)   (None, 2, 2, 1024)   262144      ['activation_132[0][0]']
#
#  identity_bn4d_branch2c (BatchN  (None, 2, 2, 1024)  4096        ['identity4d_branch2c[0][0]']
#  ormalization)
#
#  add_42 (Add)                   (None, 2, 2, 1024)   0           ['identity_bn4d_branch2c[0][0]',
#                                                                   'activation_130[0][0]']
#
#  activation_133 (Activation)    (None, 2, 2, 1024)   0           ['add_42[0][0]']
#
#  identity4e_branch2a (Conv2D)   (None, 2, 2, 256)    262144      ['activation_133[0][0]']
#
#  identity_bn4e_branch2a (BatchN  (None, 2, 2, 256)   1024        ['identity4e_branch2a[0][0]']
#  ormalization)
#
#  activation_134 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4e_branch2a[0][0]']
#
#  identity4e_branch2b (Conv2D)   (None, 2, 2, 256)    589824      ['activation_134[0][0]']
#
#  identity_bn4e_branch2b (BatchN  (None, 2, 2, 256)   1024        ['identity4e_branch2b[0][0]']
#  ormalization)
#
#  activation_135 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4e_branch2b[0][0]']
#
#  identity4e_branch2c (Conv2D)   (None, 2, 2, 1024)   262144      ['activation_135[0][0]']
#
#  identity_bn4e_branch2c (BatchN  (None, 2, 2, 1024)  4096        ['identity4e_branch2c[0][0]']
#  ormalization)
#
#  add_43 (Add)                   (None, 2, 2, 1024)   0           ['identity_bn4e_branch2c[0][0]',
#                                                                   'activation_133[0][0]']
#
#  activation_136 (Activation)    (None, 2, 2, 1024)   0           ['add_43[0][0]']
#
#  identity4f_branch2a (Conv2D)   (None, 2, 2, 256)    262144      ['activation_136[0][0]']
#
#  identity_bn4f_branch2a (BatchN  (None, 2, 2, 256)   1024        ['identity4f_branch2a[0][0]']
#  ormalization)
#
#  activation_137 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4f_branch2a[0][0]']
#
#  identity4f_branch2b (Conv2D)   (None, 2, 2, 256)    589824      ['activation_137[0][0]']
#
#  identity_bn4f_branch2b (BatchN  (None, 2, 2, 256)   1024        ['identity4f_branch2b[0][0]']
#  ormalization)
#
#  activation_138 (Activation)    (None, 2, 2, 256)    0           ['identity_bn4f_branch2b[0][0]']
#
#  identity4f_branch2c (Conv2D)   (None, 2, 2, 1024)   262144      ['activation_138[0][0]']
#
#  identity_bn4f_branch2c (BatchN  (None, 2, 2, 1024)  4096        ['identity4f_branch2c[0][0]']
#  ormalization)
#
#  add_44 (Add)                   (None, 2, 2, 1024)   0           ['identity_bn4f_branch2c[0][0]',
#                                                                   'activation_136[0][0]']
#
#  activation_139 (Activation)    (None, 2, 2, 1024)   0           ['add_44[0][0]']
#
#  conv5a_branch2a (Conv2D)       (None, 2, 2, 512)    524288      ['activation_139[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 2, 512)   2048        ['conv5a_branch2a[0][0]']
#  ion)
#
#  activation_140 (Activation)    (None, 2, 2, 512)    0           ['bn5a_branch2a[0][0]']
#
#  conv5a_branch2b (Conv2D)       (None, 1, 1, 512)    2359296     ['activation_140[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2b[0][0]']
#  ion)
#
#  activation_141 (Activation)    (None, 1, 1, 512)    0           ['bn5a_branch2b[0][0]']
#
#  conv5a_branch2c (Conv2D)       (None, 1, 1, 2048)   1048576     ['activation_141[0][0]']
#
#  conv5a_branch1 (Conv2D)        (None, 1, 1, 2048)   2097152     ['activation_139[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 1, 1, 2048)  8192        ['conv5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 1, 1, 2048)  8192        ['conv5a_branch1[0][0]']
#  on)
#
#  add_45 (Add)                   (None, 1, 1, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_142 (Activation)    (None, 1, 1, 2048)   0           ['add_45[0][0]']
#
#  identity5b_branch2a (Conv2D)   (None, 1, 1, 512)    1048576     ['activation_142[0][0]']
#
#  identity_bn5b_branch2a (BatchN  (None, 1, 1, 512)   2048        ['identity5b_branch2a[0][0]']
#  ormalization)
#
#  activation_143 (Activation)    (None, 1, 1, 512)    0           ['identity_bn5b_branch2a[0][0]']
#
#  identity5b_branch2b (Conv2D)   (None, 1, 1, 512)    2359296     ['activation_143[0][0]']
#
#  identity_bn5b_branch2b (BatchN  (None, 1, 1, 512)   2048        ['identity5b_branch2b[0][0]']
#  ormalization)
#
#  activation_144 (Activation)    (None, 1, 1, 512)    0           ['identity_bn5b_branch2b[0][0]']
#
#  identity5b_branch2c (Conv2D)   (None, 1, 1, 2048)   1048576     ['activation_144[0][0]']
#
#  identity_bn5b_branch2c (BatchN  (None, 1, 1, 2048)  8192        ['identity5b_branch2c[0][0]']
#  ormalization)
#
#  add_46 (Add)                   (None, 1, 1, 2048)   0           ['identity_bn5b_branch2c[0][0]',
#                                                                   'activation_142[0][0]']
#
#  activation_145 (Activation)    (None, 1, 1, 2048)   0           ['add_46[0][0]']
#
#  identity5c_branch2a (Conv2D)   (None, 1, 1, 512)    1048576     ['activation_145[0][0]']
#
#  identity_bn5c_branch2a (BatchN  (None, 1, 1, 512)   2048        ['identity5c_branch2a[0][0]']
#  ormalization)
#
#  activation_146 (Activation)    (None, 1, 1, 512)    0           ['identity_bn5c_branch2a[0][0]']
#
#  identity5c_branch2b (Conv2D)   (None, 1, 1, 512)    2359296     ['activation_146[0][0]']
#
#  identity_bn5c_branch2b (BatchN  (None, 1, 1, 512)   2048        ['identity5c_branch2b[0][0]']
#  ormalization)
#
#  activation_147 (Activation)    (None, 1, 1, 512)    0           ['identity_bn5c_branch2b[0][0]']
#
#  identity5c_branch2c (Conv2D)   (None, 1, 1, 2048)   1048576     ['activation_147[0][0]']
#
#  identity_bn5c_branch2c (BatchN  (None, 1, 1, 2048)  8192        ['identity5c_branch2c[0][0]']
#  ormalization)
#
#  add_47 (Add)                   (None, 1, 1, 2048)   0           ['identity_bn5c_branch2c[0][0]',
#                                                                   'activation_145[0][0]']
#
#  activation_148 (Activation)    (None, 1, 1, 2048)   0           ['add_47[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['activation_148[0][0]']
#  obalAveragePooling2D)
#
#  fc1000 (Dense)                 (None, 100)          204900      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  activation_149 (Activation)    (None, 100)          0           ['fc1000[0][0]']
#
# ==================================================================================================
# Total params: 23,766,052
# Trainable params: 23,712,932
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
plot_model(resnet_50)

# %%
def plain_conv_blocks(input_tensor,
                      kernel_size,
                      filters,
                      stage,
                      block,
                      strides=(2,2),
                      use_l2_regularizer=True,
                      batch_norm_decay=0.9,
                      batch_norm_epsilon=1e-5):
  
  filters1,filters2,filters3=filters

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_base_name = 'conv' + str(stage) + block + '_branch'
  bn_base_name = 'bn' + str(stage) + block + '_branch'

  x = layers.Conv2D(filters1,(1,1), use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=conv_base_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters2, kernel_size, strides= strides,padding='same',use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=conv_base_name + '2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '2b')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters3,(1,1), use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=conv_base_name+'2c')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum = batch_norm_decay,
                                epsilon = batch_norm_epsilon,
                                name = bn_base_name + '2c')(x)

  x = layers.Activation('relu')(x)

  return x

# %%
def plain_identity_block(input_tensor,
                         kernel_size,
                         filters,
                         stage,
                         block,
                         use_l2_regularizer=True,
                         batch_norm_decay=0.9,
                         batch_norm_epsilon=1e-5):
  
  filters1,filters2,filters3 = filters

  if backend.image_data_format()=='channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_base_name = 'identity' + str(stage) + block + '_branch'
  bn_base_name = 'identity_bn' + str(stage) + block + '_branch'

  x = layers.Conv2D(filters1,(1,1),use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name=id_base_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=batch_norm_decay,
                                epsilon=batch_norm_epsilon,
                                name=bn_base_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters2,kernel_size,padding='same',use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_base_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                         momentum = batch_norm_decay,
                         epsilon =batch_norm_epsilon,
                         name= bn_base_name+'2b')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters3,(1,1),use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_base_name+'2c')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=batch_norm_decay,
                                epsilon=batch_norm_epsilon,
                                name=bn_base_name+'2c')(x)

  x = layers.Activation('relu')(x)

  return x

# %%
def plain50(num_classes,
            batch_size=None,
            use_l2_regularizer=True,
            rescale_inputs=False,
            batch_norm_decay=0.9,
            batch_norm_epsilon=1e-5):

  input_shape = (32, 32, 3)  # CIFAR100을 위한 input_shape 조정입니다. 
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(img_input)
    bn_axis = 1
  else:  # channels_last
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      batch_norm_decay=batch_norm_decay,
      batch_norm_epsilon=batch_norm_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(img_input)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=batch_norm_decay,
      epsilon=batch_norm_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = plain_conv_blocks(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1), **block_config)
  x = plain_identity_block(x, 3, [64, 64, 256], stage=2, block='b', **block_config)
  x = plain_identity_block(x, 3, [64, 64, 256], stage=2, block='c', **block_config)

  x = plain_conv_blocks(x, 3, [128, 128, 512], stage=3, block='a', **block_config)
  x = plain_identity_block(x, 3, [128, 128, 512], stage=3, block='b', **block_config)
  x = plain_identity_block(x, 3, [128, 128, 512], stage=3, block='c', **block_config)
  x = plain_identity_block(x, 3, [128, 128, 512], stage=3, block='d', **block_config)

  x = plain_conv_blocks(x, 3, [256, 256, 1024], stage=4, block='a', **block_config)
  x = plain_identity_block(x, 3, [256, 256, 1024], stage=4, block='b', **block_config)
  x = plain_identity_block(x, 3, [256, 256, 1024], stage=4, block='c', **block_config)
  x = plain_identity_block(x, 3, [256, 256, 1024], stage=4, block='d', **block_config)
  x = plain_identity_block(x, 3, [256, 256, 1024], stage=4, block='e', **block_config)
  x = plain_identity_block(x, 3, [256, 256, 1024], stage=4, block='f', **block_config)

  x = plain_conv_blocks(x, 3, [512, 512, 2048], stage=5, block='a', **block_config)
  x = plain_identity_block(x, 3, [512, 512, 2048], stage=5, block='b', **block_config)
  x = plain_identity_block(x, 3, [512, 512, 2048], stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(
          x)

  # A softmax that is followed by the model loss must be done cannot be done
  # in float16 due to numeric issues. So we pass dtype=float32.
  x = layers.Activation('softmax', dtype='float32')(x)

  # Create model.
  return models.Model(img_input, x, name='resnet50')

# %%
plain_50 = plain50(num_classes=100)
plain_50.summary()
# Out:
# Model: "resnet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv1_pad (ZeroPadding2D)   (None, 38, 38, 3)         0
#
#  conv1 (Conv2D)              (None, 16, 16, 64)        9408
#
#  bn_conv1 (BatchNormalizatio  (None, 16, 16, 64)       256
#  n)
#
#  activation_150 (Activation)  (None, 16, 16, 64)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2a_branch2a (Conv2D)    (None, 8, 8, 64)          4096
#
#  bn2a_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_151 (Activation)  (None, 8, 8, 64)         0
#
#  conv2a_branch2b (Conv2D)    (None, 8, 8, 64)          36864
#
#  bn2a_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_152 (Activation)  (None, 8, 8, 64)         0
#
#  conv2a_branch2c (Conv2D)    (None, 8, 8, 256)         16384
#
#  bn2a_branch2c (BatchNormali  (None, 8, 8, 256)        1024
#  zation)
#
#  activation_153 (Activation)  (None, 8, 8, 256)        0
#
#  identity2b_branch2a (Conv2D  (None, 8, 8, 64)         16384
#  )
#
#  identity_bn2b_branch2a (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_154 (Activation)  (None, 8, 8, 64)         0
#
#  identity2b_branch2b (Conv2D  (None, 8, 8, 64)         36864
#  )
#
#  identity_bn2b_branch2b (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_155 (Activation)  (None, 8, 8, 64)         0
#
#  identity2b_branch2c (Conv2D  (None, 8, 8, 256)        16384
#  )
#
#  identity_bn2b_branch2c (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_156 (Activation)  (None, 8, 8, 256)        0
#
#  identity2c_branch2a (Conv2D  (None, 8, 8, 64)         16384
#  )
#
#  identity_bn2c_branch2a (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_157 (Activation)  (None, 8, 8, 64)         0
#
#  identity2c_branch2b (Conv2D  (None, 8, 8, 64)         36864
#  )
#
#  identity_bn2c_branch2b (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  activation_158 (Activation)  (None, 8, 8, 64)         0
#
#  identity2c_branch2c (Conv2D  (None, 8, 8, 256)        16384
#  )
#
#  identity_bn2c_branch2c (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_159 (Activation)  (None, 8, 8, 256)        0
#
#  conv3a_branch2a (Conv2D)    (None, 8, 8, 128)         32768
#
#  bn3a_branch2a (BatchNormali  (None, 8, 8, 128)        512
#  zation)
#
#  activation_160 (Activation)  (None, 8, 8, 128)        0
#
#  conv3a_branch2b (Conv2D)    (None, 4, 4, 128)         147456
#
#  bn3a_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_161 (Activation)  (None, 4, 4, 128)        0
#
#  conv3a_branch2c (Conv2D)    (None, 4, 4, 512)         65536
#
#  bn3a_branch2c (BatchNormali  (None, 4, 4, 512)        2048
#  zation)
#
#  activation_162 (Activation)  (None, 4, 4, 512)        0
#
#  identity3b_branch2a (Conv2D  (None, 4, 4, 128)        65536
#  )
#
#  identity_bn3b_branch2a (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_163 (Activation)  (None, 4, 4, 128)        0
#
#  identity3b_branch2b (Conv2D  (None, 4, 4, 128)        147456
#  )
#
#  identity_bn3b_branch2b (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_164 (Activation)  (None, 4, 4, 128)        0
#
#  identity3b_branch2c (Conv2D  (None, 4, 4, 512)        65536
#  )
#
#  identity_bn3b_branch2c (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_165 (Activation)  (None, 4, 4, 512)        0
#
#  identity3c_branch2a (Conv2D  (None, 4, 4, 128)        65536
#  )
#
#  identity_bn3c_branch2a (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_166 (Activation)  (None, 4, 4, 128)        0
#
#  identity3c_branch2b (Conv2D  (None, 4, 4, 128)        147456
#  )
#
#  identity_bn3c_branch2b (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_167 (Activation)  (None, 4, 4, 128)        0
#
#  identity3c_branch2c (Conv2D  (None, 4, 4, 512)        65536
#  )
#
#  identity_bn3c_branch2c (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_168 (Activation)  (None, 4, 4, 512)        0
#
#  identity3d_branch2a (Conv2D  (None, 4, 4, 128)        65536
#  )
#
#  identity_bn3d_branch2a (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_169 (Activation)  (None, 4, 4, 128)        0
#
#  identity3d_branch2b (Conv2D  (None, 4, 4, 128)        147456
#  )
#
#  identity_bn3d_branch2b (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  activation_170 (Activation)  (None, 4, 4, 128)        0
#
#  identity3d_branch2c (Conv2D  (None, 4, 4, 512)        65536
#  )
#
#  identity_bn3d_branch2c (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_171 (Activation)  (None, 4, 4, 512)        0
#
#  conv4a_branch2a (Conv2D)    (None, 4, 4, 256)         131072
#
#  bn4a_branch2a (BatchNormali  (None, 4, 4, 256)        1024
#  zation)
#
#  activation_172 (Activation)  (None, 4, 4, 256)        0
#
#  conv4a_branch2b (Conv2D)    (None, 2, 2, 256)         589824
#
#  bn4a_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_173 (Activation)  (None, 2, 2, 256)        0
#
#  conv4a_branch2c (Conv2D)    (None, 2, 2, 1024)        262144
#
#  bn4a_branch2c (BatchNormali  (None, 2, 2, 1024)       4096
#  zation)
#
#  activation_174 (Activation)  (None, 2, 2, 1024)       0
#
#  identity4b_branch2a (Conv2D  (None, 2, 2, 256)        262144
#  )
#
#  identity_bn4b_branch2a (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_175 (Activation)  (None, 2, 2, 256)        0
#
#  identity4b_branch2b (Conv2D  (None, 2, 2, 256)        589824
#  )
#
#  identity_bn4b_branch2b (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_176 (Activation)  (None, 2, 2, 256)        0
#
#  identity4b_branch2c (Conv2D  (None, 2, 2, 1024)       262144
#  )
#
#  identity_bn4b_branch2c (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  activation_177 (Activation)  (None, 2, 2, 1024)       0
#
#  identity4c_branch2a (Conv2D  (None, 2, 2, 256)        262144
#  )
#
#  identity_bn4c_branch2a (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_178 (Activation)  (None, 2, 2, 256)        0
#
#  identity4c_branch2b (Conv2D  (None, 2, 2, 256)        589824
#  )
#
#  identity_bn4c_branch2b (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_179 (Activation)  (None, 2, 2, 256)        0
#
#  identity4c_branch2c (Conv2D  (None, 2, 2, 1024)       262144
#  )
#
#  identity_bn4c_branch2c (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  activation_180 (Activation)  (None, 2, 2, 1024)       0
#
#  identity4d_branch2a (Conv2D  (None, 2, 2, 256)        262144
#  )
#
#  identity_bn4d_branch2a (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_181 (Activation)  (None, 2, 2, 256)        0
#
#  identity4d_branch2b (Conv2D  (None, 2, 2, 256)        589824
#  )
#
#  identity_bn4d_branch2b (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_182 (Activation)  (None, 2, 2, 256)        0
#
#  identity4d_branch2c (Conv2D  (None, 2, 2, 1024)       262144
#  )
#
#  identity_bn4d_branch2c (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  activation_183 (Activation)  (None, 2, 2, 1024)       0
#
#  identity4e_branch2a (Conv2D  (None, 2, 2, 256)        262144
#  )
#
#  identity_bn4e_branch2a (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_184 (Activation)  (None, 2, 2, 256)        0
#
#  identity4e_branch2b (Conv2D  (None, 2, 2, 256)        589824
#  )
#
#  identity_bn4e_branch2b (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_185 (Activation)  (None, 2, 2, 256)        0
#
#  identity4e_branch2c (Conv2D  (None, 2, 2, 1024)       262144
#  )
#
#  identity_bn4e_branch2c (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  activation_186 (Activation)  (None, 2, 2, 1024)       0
#
#  identity4f_branch2a (Conv2D  (None, 2, 2, 256)        262144
#  )
#
#  identity_bn4f_branch2a (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_187 (Activation)  (None, 2, 2, 256)        0
#
#  identity4f_branch2b (Conv2D  (None, 2, 2, 256)        589824
#  )
#
#  identity_bn4f_branch2b (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  activation_188 (Activation)  (None, 2, 2, 256)        0
#
#  identity4f_branch2c (Conv2D  (None, 2, 2, 1024)       262144
#  )
#
#  identity_bn4f_branch2c (Bat  (None, 2, 2, 1024)       4096
#  chNormalization)
#
#  activation_189 (Activation)  (None, 2, 2, 1024)       0
#
#  conv5a_branch2a (Conv2D)    (None, 2, 2, 512)         524288
#
#  bn5a_branch2a (BatchNormali  (None, 2, 2, 512)        2048
#  zation)
#
#  activation_190 (Activation)  (None, 2, 2, 512)        0
#
#  conv5a_branch2b (Conv2D)    (None, 1, 1, 512)         2359296
#
#  bn5a_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_191 (Activation)  (None, 1, 1, 512)        0
#
#  conv5a_branch2c (Conv2D)    (None, 1, 1, 2048)        1048576
#
#  bn5a_branch2c (BatchNormali  (None, 1, 1, 2048)       8192
#  zation)
#
#  activation_192 (Activation)  (None, 1, 1, 2048)       0
#
#  identity5b_branch2a (Conv2D  (None, 1, 1, 512)        1048576
#  )
#
#  identity_bn5b_branch2a (Bat  (None, 1, 1, 512)        2048
#  chNormalization)
#
#  activation_193 (Activation)  (None, 1, 1, 512)        0
#
#  identity5b_branch2b (Conv2D  (None, 1, 1, 512)        2359296
#  )
#
#  identity_bn5b_branch2b (Bat  (None, 1, 1, 512)        2048
#  chNormalization)
#
#  activation_194 (Activation)  (None, 1, 1, 512)        0
#
#  identity5b_branch2c (Conv2D  (None, 1, 1, 2048)       1048576
#  )
#
#  identity_bn5b_branch2c (Bat  (None, 1, 1, 2048)       8192
#  chNormalization)
#
#  activation_195 (Activation)  (None, 1, 1, 2048)       0
#
#  identity5c_branch2a (Conv2D  (None, 1, 1, 512)        1048576
#  )
#
#  identity_bn5c_branch2a (Bat  (None, 1, 1, 512)        2048
#  chNormalization)
#
#  activation_196 (Activation)  (None, 1, 1, 512)        0
#
#  identity5c_branch2b (Conv2D  (None, 1, 1, 512)        2359296
#  )
#
#  identity_bn5c_branch2b (Bat  (None, 1, 1, 512)        2048
#  chNormalization)
#
#  activation_197 (Activation)  (None, 1, 1, 512)        0
#
#  identity5c_branch2c (Conv2D  (None, 1, 1, 2048)       1048576
#  )
#
#  identity_bn5c_branch2c (Bat  (None, 1, 1, 2048)       8192
#  chNormalization)
#
#  activation_198 (Activation)  (None, 1, 1, 2048)       0
#
#  global_average_pooling2d_3   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  fc1000 (Dense)              (None, 100)               204900
#
#  activation_199 (Activation)  (None, 100)              0
#
# =================================================================
# Total params: 20,981,796
# Trainable params: 20,936,356
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
plot_model(plain_50)
